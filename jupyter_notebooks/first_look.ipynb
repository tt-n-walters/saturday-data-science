# %% [markdown]
# This is normal text
# # This is a header 1
# ## This is header 2
# ### This header 3
#
# ```
# def function(a, b):
#     return a + b
# ```
#
# [Click here to go the Python website](https://www.python.org)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
x_values = np.linspace(0, np.pi * 4, 100)
y_values = np.sin(x_values)
plt.plot(x_values, y_values)

# %%
Out
# Out:
# {3: [<matplotlib.lines.Line2D at 0x1f8ff8cbf10>]}
